# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(1,1, figsize=(6,4))
ax.set_xlim(0.001, 1e2)
ax.set_ylim(1e-11, 1e3)
ax.grid()
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('f[cpd]')
ax.set_ylabel(r'PDS[$m^2/s^2$/cpd]')
# Out:
# Text(0, 0.5, 'PDS[$m^2/s^2$/cpd]')
