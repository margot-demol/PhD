# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
rd = sorted(np.random.rand(20))
rd2 = np.random.rand(20)
true = np.power(rd, 2)+rd+1+rd2

# %%
i=7

# %%
plt.scatter(rd, true, marker = '+')
plt.grid()
