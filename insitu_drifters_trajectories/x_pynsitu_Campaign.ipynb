# %%
import pynsitu as pin
from lib import raw_dir, root_dir, images_dir, KEYS

# %%
cp = pin.Campaign(root_dir + '/drifters_CSWOT_BIOSWOT.yaml')

# %%
cp["cswot_leg1"].start.time, cp["cswot_leg1"].end.time
# Out:
# (Timestamp('2022-09-21 06:30:00'), Timestamp('2022-09-25 15:10:00'))

# %%
cp["cswot_leg1"].meta
# Out:
# {'platforms': 'europe drix',
#  'color': 'black',
#  'duration_days': 4.361111111111111}

# %%
cp["cswot_leg1"]["color"]
# Out:
# 'black'

# %%
cp.timeline()
# Out:
# <AxesSubplot: title={'center': 'drifters_CSWOT_BIOSWOT'}>

# %%
cp = pin.Campaign(root_dir + '/drifters_UWA.yaml')

# %%
cp.timeline()
# Out:
# <AxesSubplot: title={'center': 'drifters_UWA'}>
