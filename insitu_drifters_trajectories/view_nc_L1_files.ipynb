# %% [markdown]
# # RAW FILES
# - Nom du fichier global stocké dans raw : type_source_datemax_heuremax.csv
# - var name : id, time, lon, lat
# - time en timestamp
# - id en str
# - index = id
#
# ## NC attrs
# - drifter type
# - campaign
# - drifter_number
# - download_date
# - version
# - contact

# %%
key = KEYS[0]
path = glob(os.path.join(raw_dir, "L1_" + key + "*" +".nc"))[0]
ds = xr.open_dataset(path)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:             (id: 20, time: 114798)
# Coordinates:
#   * id                  (id) object '0-4388553' '0-4388559' ... '0-4389467'
#   * time                (time) datetime64[ns] 2023-04-23T18:03:46 ... 2023-06...
# Data variables: (12/19)
#     GpsQuality          (id, time) float64 ...
#     lat                 (id, time) float64 ...
#     lon                 (id, time) float64 ...
#     BatteryStatus       (id, time) object ...
#     GPS Confidence      (id, time) float64 ...
#     GPS Fail Counter    (id, time) float64 ...
#     ...                  ...
#     velocity            (id, time) float64 ...
#     acceleration_east   (id, time) float64 ...
#     acceleration_north  (id, time) float64 ...
#     acceleration        (id, time) float64 ...
#     lonc                (id, time) float64 ...
#     latc                (id, time) float64 ...
# Attributes:
#     description:            L1 product - Retrieve value before deployment and...
#     drifter_type:           CARTHE (Pacific Gyre)
#     laboratory:             CNR
#     campaign:               BIOSWOT
#     campaign_doi:           https://doi.org/10.17600/18002392
#     raw_download_max_date:  2023-06-26 05:34:53
#     contact:                margot.demol@ifremer.fr
#     generation_date:        2023-09-15 09:11:01.061681
